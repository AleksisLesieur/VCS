# %% [markdown]
# 1. Iš pirmų 100 skaičių, jeigu skaičius dalinasi iš 2 be liekanos, atspausdinkite `Fizz`, jeigu skaičius dalinasi iš 3 be liekanos atspausdinkite `Buzz`, jei skaičius dalinasi iš 2 ir 3 be liekanos, atspausdinkite `FizzBuzz`
# Pvz:
# 1 - ''
# 2 - 'Fizz'
# 3 - 'Buzz'
# 4 - 'Fizz'
# 5 - ''
# 6 - 'FizzBuzz'

# %%
for num in range (1, 101):
    if num % 6 == 0:
        print(num, '- FizzBuzz')
    elif num % 2 == 0:
        print(num, '- Fizz')
    elif num % 3 == 0:
        print(num, '- Buzz')
    else:
        print(num, '- ')
# Out:
# 1 -
# 2 - Fizz
# 3 - Buzz
# 4 - Fizz
# 5 -
# 6 - FizzBuzz
# 7 -
# 8 - Fizz
# 9 - Buzz
# 10 - Fizz
# 11 -
# 12 - FizzBuzz
# 13 -
# 14 - Fizz
# 15 - Buzz
# 16 - Fizz
# 17 -
# 18 - FizzBuzz
# 19 -
# 20 - Fizz
# 21 - Buzz
# 22 - Fizz
# 23 -
# 24 - FizzBuzz
# 25 -
# 26 - Fizz
# 27 - Buzz
# 28 - Fizz
# 29 -
# 30 - FizzBuzz
# 31 -
# 32 - Fizz
# 33 - Buzz
# 34 - Fizz
# 35 -
# 36 - FizzBuzz
# 37 -
# 38 - Fizz
# 39 - Buzz
# 40 - Fizz
# 41 -
# 42 - FizzBuzz
# 43 -
# 44 - Fizz
# 45 - Buzz
# 46 - Fizz
# 47 -
# 48 - FizzBuzz
# 49 -
# 50 - Fizz
# 51 - Buzz
# 52 - Fizz
# 53 -
# 54 - FizzBuzz
# 55 -
# 56 - Fizz
# 57 - Buzz
# 58 - Fizz
# 59 -
# 60 - FizzBuzz
# 61 -
# 62 - Fizz
# 63 - Buzz
# 64 - Fizz
# 65 -
# 66 - FizzBuzz
# 67 -
# 68 - Fizz
# 69 - Buzz
# 70 - Fizz
# 71 -
# 72 - FizzBuzz
# 73 -
# 74 - Fizz
# 75 - Buzz
# 76 - Fizz
# 77 -
# 78 - FizzBuzz
# 79 -
# 80 - Fizz
# 81 - Buzz
# 82 - Fizz
# 83 -
# 84 - FizzBuzz
# 85 -
# 86 - Fizz
# 87 - Buzz
# 88 - Fizz
# 89 -
# 90 - FizzBuzz
# 91 -
# 92 - Fizz
# 93 - Buzz
# 94 - Fizz
# 95 -
# 96 - FizzBuzz
# 97 -
# 98 - Fizz
# 99 - Buzz
# 100 - Fizz

# %% [markdown]
# 2. Leiskite vartotojui pasirinkti skaičių, jeigu įvestas skaičius yra daugiau arba lygus 10, einant per skaičius nuo 1 iki pasirinkto skaičiaus, atspausdinkite visus skaičius kurie dalinasi iš 5 su liekana

# %%
# num = int(input('choose a number'))
if num >= 10:
    for i in range(1, num):
        if i % 5 != 0:
            print(i)
# Out:
# 1
# 2
# 3
# 4
# 6
# 7
# 8
# 9
# 11
# 12
# 13
# 14
# 16
# 17
# 18
# 19
# 21
# 22
# 23
# 24
# 26
# 27
# 28
# 29
# 31
# 32
# 33
# 34
# 36
# 37
# 38
# 39
# 41
# 42
# 43
# 44
# 46
# 47
# 48
# 49
# 51
# 52
# 53
# 54
# 56
# 57
# 58
# 59
# 61
# 62
# 63
# 64
# 66
# 67
# 68
# 69
# 71
# 72
# 73
# 74
# 76
# 77
# 78
# 79
# 81
# 82
# 83
# 84
# 86
# 87
# 88
# 89
# 91
# 92
# 93
# 94
# 96
# 97
# 98
# 99

# %% [markdown]
# 3. Koks yra sąrašo ilgis sudaryto iš pateiktų sąrašų kombinacijų, jeigu norime rasti visas įmanomas reikšmes? Išrikiuokite sąrašą nuo didžiausios iki mažiausios reikšmės (teks atlikti papildomų veiksmų tam atlikti teisingai, naudoti viena iš 3 narių rikiavimui)

# %%
a = ['1','2','3','4','5']
b = ['labas', 'vakaras', 'kokia grazi diena', 'siandien uz lango', '10 laipsniu silumos']
c = ['100', '200', 40, 10]

# supratau uzduoties visiskai, tad darau taip kaip supratau

all_list = a + b + c

for i in range(len(all_list)):
    if isinstance(all_list[i], (int, float)):
        all_list[i] = str(all_list[i])

print(sorted(all_list)[::-1])
# Out:
# ['vakaras', 'siandien uz lango', 'labas', 'kokia grazi diena', '5', '40', '4', '3', '200', '2', '100', '10 laipsniu silumos', '10', '1']
